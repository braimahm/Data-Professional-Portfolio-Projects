# %%
 ''' The code interpolates the 1nm reflectance to 10nm
 and computes derivatives'''

 #importing packages
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive')
import seaborn as sns
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
""" We want to load the excel book and call each weeksheet.
This saves us time from saving each worksheet seperately
"""

ZachA_LynnW = pd.ExcelFile('/content/042623_HWHF_10d_1_1.xlsx')
ZachA_15_Weeds = pd.read_excel(ZachA_LynnW, 'ZachA_15_Weeds')
ZachA_15_Weeds['Mean Reflectance'] = ZachA_15_Weeds.drop('Wavelength', axis=1).mean(axis=1)*100

ZachA_15_Soil = pd.read_excel(ZachA_LynnW, 'ZachA15_Soil')
ZachA_15_Soil['Mean Reflectance'] = ZachA_15_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

ZachA_14_Weeds = pd.read_excel(ZachA_LynnW, 'ZachA_14_Weeds')
ZachA_14_Weeds['Mean Reflectance'] = ZachA_14_Weeds.drop('Wavelength', axis=1).mean(axis=1)*100

ZachA_14_Soil = pd.read_excel(ZachA_LynnW, 'ZachA14_Soil')
ZachA_14_Soil['Mean Reflectance'] = ZachA_14_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

ZachA_13_Weeds = pd.read_excel(ZachA_LynnW, 'ZachA13_Weeds')
ZachA_13_Weeds['Mean Reflectance'] = ZachA_13_Weeds.drop('Wavelength', axis=1).mean(axis=1)*100

ZachA_13_Soil = pd.read_excel(ZachA_LynnW, 'ZachA13_10D_Soil')
ZachA_13_Soil['Mean Reflectance'] = ZachA_13_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

ZachA_12_Wheat = pd.read_excel(ZachA_LynnW, 'ZachA12_Wheat')
ZachA_12_Wheat['Mean Reflectance'] = ZachA_12_Wheat.drop('Wavelength', axis=1).mean(axis=1)*100

ZachA_12_Road = pd.read_excel(ZachA_LynnW, 'ZachA12_Road')
ZachA_12_Road['Mean Reflectance'] = ZachA_12_Road.drop('Wavelength', axis=1).mean(axis=1)*100

ZachA_11_Wheat = pd.read_excel(ZachA_LynnW, 'ZackA_11_Wheat')
ZachA_11_Wheat['Mean Reflectance'] = ZachA_11_Wheat.drop('Wavelength', axis=1).mean(axis=1)*100

ZachA_11_Soil = pd.read_excel(ZachA_LynnW, 'ZachA11_Soil')
ZachA_11_Soil['Mean Reflectance'] = ZachA_11_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

LynnW05_CornRes = pd.read_excel(ZachA_LynnW, '042623_LynnW05_Cornres')
LynnW05_CornRes['Mean Reflectance'] = LynnW05_CornRes.drop('Wavelength', axis=1).mean(axis=1)*100

LynnW05_Soil = pd.read_excel(ZachA_LynnW, '042623_LynnW05_Bare_Soil')
LynnW05_Soil['Mean Reflectance'] = LynnW05_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

LynnW04_CornRes = pd.read_excel(ZachA_LynnW, '042623_LynnW04_Cornres')
LynnW04_CornRes['Mean Reflectance'] = LynnW04_CornRes.drop('Wavelength', axis=1).mean(axis=1)*100

LynnW04_Soil = pd.read_excel(ZachA_LynnW, '042623LynnW04_Bare_SOil')
LynnW04_Soil['Mean Reflectance'] = LynnW04_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

LynnW03_CornRes = pd.read_excel(ZachA_LynnW, '042623_LynnW03_Cornres')
LynnW03_CornRes['Mean Reflectance'] = LynnW03_CornRes.drop('Wavelength', axis=1).mean(axis=1)*100

LynnW03_Soil = pd.read_excel(ZachA_LynnW, '042623LynnW_03_Bare_Soil')
LynnW03_Soil['Mean Reflectance'] = LynnW03_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

LynnW02_CornRes = pd.read_excel(ZachA_LynnW, '042623_LynnW02_Cornres')
LynnW02_CornRes['Mean Reflectance'] = LynnW02_CornRes.drop('Wavelength', axis=1).mean(axis=1)*100

LynnW02_Soil = pd.read_excel(ZachA_LynnW, '042623_LynnW02_Bare_Soil')
LynnW02_Soil['Mean Reflectance'] = LynnW02_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

LynnW01_CornRes = pd.read_excel(ZachA_LynnW, '042623_LynnW01_Cornres')
LynnW01_CornRes['Mean Reflectance'] = LynnW01_CornRes.drop('Wavelength', axis=1).mean(axis=1)*100

LynnW01_Soil = pd.read_excel(ZachA_LynnW, '042623_LynnW01_Bare_Soil')
LynnW01_Soil['Mean Reflectance'] = LynnW01_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

# %%
SK_farms = pd.ExcelFile('/content/052423_HWHF_10d_1.xlsx')

SK_5_Soil = pd.read_excel(SK_farms, '052423_SK_5_Soil')
SK_5_Soil["Mean Reflectance"] = SK_5_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

SK_5_Grass = pd.read_excel(SK_farms, '052423_SK_5_Grass')
SK_5_Grass["Mean Reflectance"] = SK_5_Grass.drop('Wavelength', axis=1).mean(axis=1)*100

SK_4_Soil = pd.read_excel(SK_farms, '052423_SK_4_Soil')
SK_4_Soil["Mean Reflectance"] = SK_4_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

SK_4_Grass = pd.read_excel(SK_farms, '052423_SK_4_Grass')
SK_4_Grass["Mean Reflectance"] = SK_4_Grass.drop('Wavelength', axis=1).mean(axis=1)*100

SK_3_Soil = pd.read_excel(SK_farms, '052423_SK_3_Soil')
SK_3_Soil["Mean Reflectance"] = SK_3_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

SK_3_Grass = pd.read_excel(SK_farms, '052423_SK_3_Grass')
SK_3_Grass["Mean Reflectance"] = SK_3_Grass.drop('Wavelength', axis=1).mean(axis=1)*100

SK_2_Soil = pd.read_excel(SK_farms, '052423_SK_2_Soil')
SK_2_Soil["Mean Reflectance"] = SK_2_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

SK_2_Grass = pd.read_excel(SK_farms, '052423_SK_2_Grass')
SK_2_Grass["Mean Reflectance"] = SK_2_Grass.drop('Wavelength', axis=1).mean(axis=1)*100

SK_1_Soil = pd.read_excel(SK_farms, '052423_SK_1_Soil')
SK_1_Soil["Mean Reflectance"] = SK_1_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

SK_1_Grass = pd.read_excel(SK_farms, '052423_SK_1_Grass')
SK_1_Grass["Mean Reflectance"] = SK_1_Grass.drop('Wavelength', axis=1).mean(axis=1)*100

# %%
KB_farms = pd.ExcelFile('/content/052223_HWHF_10d_1.xlsx')

KB_5_Wheat = pd.read_excel(KB_farms, '52223_KB5_Wheat')
KB_5_Wheat["Mean Reflectance"] = KB_5_Wheat.drop('Wavelength', axis=1).mean(axis=1)*100

KB_5_Soil = pd.read_excel(KB_farms, '052223_KB5_Soil')
KB_5_Soil["Mean Reflectance"] = KB_5_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

KB_5_Drying_Wheat = pd.read_excel(KB_farms, '052223_KB5_Drying_Wheat')
KB_5_Drying_Wheat["Mean Reflectance"] = KB_5_Drying_Wheat.drop('Wavelength', axis=1).mean(axis=1)*100

KB_5_Corn_Res = pd.read_excel(KB_farms, '052223_KB5_Corn_Res')
KB_5_Corn_Res["Mean Reflectance"] = KB_5_Corn_Res.drop('Wavelength', axis=1).mean(axis=1)*100

KB_4_Soil = pd.read_excel(KB_farms, '052223_KB4_Soil')
KB_4_Soil["Mean Reflectance"] = KB_4_Soil.drop('Wavelength', axis=1).mean(axis=1)*100


KB_4_Dry_Rye = pd.read_excel(KB_farms, '052223_KB4_Dry_Rye')
KB_4_Dry_Rye["Mean Reflectance"] = KB_4_Dry_Rye.drop('Wavelength', axis=1).mean(axis=1)*100

KB_4_Corn_Res = pd.read_excel(KB_farms, '052223_KB4_Corn_Res')
KB_4_Corn_Res["Mean Reflectance"] = KB_4_Corn_Res.drop('Wavelength', axis=1).mean(axis=1)*100

KB_3_Soil = pd.read_excel(KB_farms, '052223_KB3_Soil')
KB_3_Soil["Mean Reflectance"] = KB_3_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

KB_3_Corn_Res = pd.read_excel(KB_farms, '052223_KB_3_Corn_Res')
KB_3_Corn_Res["Mean Reflectance"] = KB_3_Corn_Res.drop('Wavelength', axis=1).mean(axis=1)*100

KB_1_Soil = pd.read_excel(KB_farms, '052223_KB1_Soil')
KB_1_Soil["Mean Reflectance"] = KB_1_Soil.drop('Wavelength', axis=1).mean(axis=1)*100
KB_1_Corn_Res = pd.read_excel(KB_farms, '052223_KB1_Corn_Res')
KB_1_Corn_Res["Mean Reflectance"] = KB_1_Corn_Res.drop('Wavelength', axis=1).mean(axis=1)*100

JB_5_Soil = pd.read_excel(KB_farms, '052223_JB5_Soil')
JB_5_Soil["Mean Reflectance"] = JB_5_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

JB_5_Corn_Res = pd.read_excel(KB_farms, '052223_JB5_Corn_Res')
JB_5_Corn_Res["Mean Reflectance"] = JB_5_Corn_Res.drop('Wavelength', axis=1).mean(axis=1)*100

JB_4_Soil = pd.read_excel(KB_farms, '052223_JB4_Soil')
JB_4_Soil["Mean Reflectance"] = JB_4_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

JB_4_Corn_Res = pd.read_excel(KB_farms, '052223_JB4_CorenRes')
JB_4_Corn_Res["Mean Reflectance"] = JB_4_Corn_Res.drop('Wavelength', axis=1).mean(axis=1)*100

JB_3_Soil = pd.read_excel(KB_farms, '052223_JB3_Soil')
JB_3_Soil["Mean Reflectance"] = JB_3_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

JB_3_Corn_Res = pd.read_excel(KB_farms, '052223_JB3_Corn_Residue')
JB_3_Corn_Res["Mean Reflectance"] = JB_3_Corn_Res.drop('Wavelength', axis=1).mean(axis=1)*100

JB_2_Soil = pd.read_excel(KB_farms, '052223_JB2_Soil')
JB_2_Soil["Mean Reflectance"] = JB_2_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

JB_2_Corn_Res = pd.read_excel(KB_farms, '052223_JB2_Corn_Residue')
JB_2_Corn_Res["Mean Reflectance"] = JB_2_Corn_Res.drop('Wavelength', axis=1).mean(axis=1)*100

JB_1_Soil = pd.read_excel(KB_farms, '052223_JB1_Soil')
JB_1_Soil["Mean Reflectance"] = JB_1_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

JB_1_Corn_Res = pd.read_excel(KB_farms, '052223_JB1_CornRes')
JB_1_Corn_Res["Mean Reflectance"] = JB_1_Corn_Res.drop('Wavelength', axis=1).mean(axis=1)*100

JB_1_Soya_Bean = pd.read_excel(KB_farms, '052223_JB1_Soya_Bean')
JB_1_Soya_Bean["Mean Reflectance"] = JB_1_Soya_Bean.drop('Wavelength', axis=1).mean(axis=1)*100

JB_Grass_Filt = pd.read_excel(KB_farms, '052223_JB_Grass_Filt')
JB_Grass_Filt["Mean Reflectance"] = JB_Grass_Filt.drop('Wavelength', axis=1).mean(axis=1)*100

JB_0_Road = pd.read_excel(KB_farms, '052223_JB0_Road')
JB_0_Road["Mean Reflectance"] = JB_0_Road.drop('Wavelength', axis=1).mean(axis=1)*100

# %%
JanD_farms = pd.ExcelFile('/content/041923_HWHF_10d_1_1.xlsx')

JanD_S10_Weeds = pd.read_excel(JanD_farms, '041923_JanDS10_Weeds')
JanD_S10_Weeds["Mean Reflectance"] = JanD_S10_Weeds.drop('Wavelength', axis=1).mean(axis=1)*100

JanD_S9_Weeds = pd.read_excel(JanD_farms, '041923_JanDS09_Weeds')
JanD_S9_Weeds["Mean Reflectance"] = JanD_S9_Weeds.drop('Wavelength', axis=1).mean(axis=1)*100

JanD_S9_Corn_Res = pd.read_excel(JanD_farms, '041923_JanDS09_Cornres')
JanD_S9_Corn_Res["Mean Reflectance"] = JanD_S9_Corn_Res.drop('Wavelength', axis=1).mean(axis=1)*100

JanD_S8_Corn_Res = pd.read_excel(JanD_farms, '041923_JanDS08_Cornres')
JanD_S8_Corn_Res["Mean Reflectance"] = JanD_S8_Corn_Res.drop('Wavelength', axis=1).mean(axis=1)*100

JanD_S8_Bare_Soil = pd.read_excel(JanD_farms, '041923JanDS08_Baresoil')
JanD_S8_Bare_Soil["Mean Reflectance"] = JanD_S8_Bare_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

JanD_S6_Weed = pd.read_excel(JanD_farms, '041923_JanDS06_Weed')
JanD_S6_Weed["Mean Reflectance"] = JanD_S6_Weed.drop('Wavelength', axis=1).mean(axis=1)*100

JanD_S6_Weed_2 = pd.read_excel(JanD_farms, '041923_JanDS06_Weed2')
JanD_S6_Weed_2["Mean Reflectance"] = JanD_S6_Weed_2.drop('Wavelength', axis=1).mean(axis=1)*100

JanD_S6_Weed_3 = pd.read_excel(JanD_farms, '041923_JanDS06_Weed3')
JanD_S6_Weed_3["Mean Reflectance"] = JanD_S6_Weed_3.drop('Wavelength', axis=1).mean(axis=1)*100

JanD_S6_Bare_Soil = pd.read_excel(JanD_farms, '041923_JanDS06_Baresoil')
JanD_S6_Bare_Soil["Mean Reflectance"] = JanD_S6_Bare_Soil.drop('Wavelength', axis=1).mean(axis=1)*100

JanD_S6_Corn_Redw = pd.read_excel(JanD_farms, '041923JanDS06_Corn_Redw')
JanD_S6_Corn_Redw["Mean Reflectance"] = JanD_S6_Corn_Redw.drop('Wavelength', axis=1).mean(axis=1)*100

# %%
'''We want to  plot the average reflectance
for 1nm wavelength. This was plotted after the atmospheric corrections
had been done in excel
'''
fig,axs = plt.subplots(2,2, figsize =(10,10))
axs[0,0].plot(ZachA_15_Weeds['Wavelength'], ZachA_15_Weeds['Mean Reflectance'])
axs[0,0].plot(ZachA_14_Weeds['Wavelength'], ZachA_14_Weeds['Mean Reflectance'])
axs[0,0].plot(ZachA_13_Weeds['Wavelength'], ZachA_13_Weeds['Mean Reflectance'])
axs[0,0].plot(ZachA_12_Wheat['Wavelength'], ZachA_12_Wheat['Mean Reflectance'])
axs[0,0].plot(ZachA_11_Wheat['Wavelength'], ZachA_11_Wheat['Mean Reflectance'])
axs[0,0].plot(ZachA_12_Road['Wavelength'], ZachA_12_Road['Mean Reflectance'])
axs[0,0].set_title("Zach A Farms - Weeds: April 26, 2023")
axs[0,0].set_xlabel('Wavelength')
axs[0,0].set_ylabel('Reflectance')

axs[0,1].plot(ZachA_15_Soil['Wavelength'], ZachA_15_Soil['Mean Reflectance'])
axs[0,1].plot(ZachA_14_Soil['Wavelength'], ZachA_14_Soil['Mean Reflectance'])
axs[0,1].plot(ZachA_13_Soil['Wavelength'], ZachA_13_Soil['Mean Reflectance'])
axs[0,1].plot(ZachA_11_Soil['Wavelength'], ZachA_11_Soil['Mean Reflectance'])
axs[0,1].set_title("Zach A Farms - Bare Soil: April 26, 2023")
axs[0,1].set_xlabel('Wavelength')
axs[0,1].set_ylabel('Reflectance')


axs[1,0].plot(LynnW05_Soil['Wavelength'], LynnW05_Soil['Mean Reflectance'])
axs[1,0].plot(LynnW04_Soil['Wavelength'], LynnW04_Soil['Mean Reflectance'])
axs[1,0].plot(LynnW03_Soil['Wavelength'], LynnW03_Soil['Mean Reflectance'])
axs[1,0].plot(LynnW02_Soil['Wavelength'], LynnW02_Soil['Mean Reflectance'])
axs[1,0].plot(LynnW01_Soil['Wavelength'], LynnW01_Soil['Mean Reflectance'])
axs[1,0].set_title("Lynn W Farms - Bare Soil: April 26, 2023")
axs[1,0].set_xlabel('Wavelength')
axs[1,0].set_ylabel('Reflectance')

axs[1,1].plot(LynnW05_CornRes['Wavelength'], LynnW05_CornRes['Mean Reflectance'])
axs[1,1].plot(LynnW04_CornRes['Wavelength'], LynnW04_CornRes['Mean Reflectance'])
axs[1,1].plot(LynnW03_CornRes['Wavelength'], LynnW03_CornRes['Mean Reflectance'])
axs[1,1].plot(LynnW02_CornRes['Wavelength'], LynnW02_CornRes['Mean Reflectance'])
axs[1,1].plot(LynnW01_CornRes['Wavelength'], LynnW01_CornRes['Mean Reflectance'])
axs[1,1].set_title("Lynn W Farms - Corn Residue: April 26, 2023")
axs[1,1].set_xlabel('Wavelength')
axs[1,1].set_ylabel('Reflectance')
# Out:
# Text(0, 0.5, 'Reflectance')

# %%
xvals = np.array(range(350, 2501, 10))
Wavelength_np = np.array(SK_5_Soil["Wavelength"])
SK_5_Soil_np= np.array( SK_5_Soil['Mean Reflectance'])
SK_5_Grass_np= np.array( SK_5_Grass['Mean Reflectance'])
SK_4_Soil_np= np.array( SK_4_Soil['Mean Reflectance'])
SK_4_Grass_np= np.array( SK_4_Grass['Mean Reflectance'])
SK_3_Soil_np= np.array( SK_3_Soil['Mean Reflectance'])
SK_3_Grass_np= np.array( SK_3_Grass['Mean Reflectance'])
SK_2_Soil_np= np.array( SK_2_Soil['Mean Reflectance'])
SK_2_Grass_np= np.array( SK_2_Grass['Mean Reflectance'])
SK_1_Soil_np= np.array( SK_1_Soil['Mean Reflectance'])
SK_1_Grass_np= np.array( SK_1_Grass['Mean Reflectance'])

Wavelength_np = np.array(KB_5_Soil["Wavelength"])
KB_5_Wheat_np = np.array(KB_5_Wheat['Mean Reflectance'])
KB_5_Soil_np = np.array(KB_5_Soil['Mean Reflectance'])
KB_5_Drying_Wheat_np = np.array(KB_5_Drying_Wheat['Mean Reflectance'])
KB_5_Corn_Res_np = np.array(KB_5_Corn_Res["Mean Reflectance"])
KB_4_Soil_np = np.array(KB_4_Soil['Mean Reflectance'])
KB_4_Dry_Rye_np = np.array(KB_4_Dry_Rye['Mean Reflectance'])
KB_3_Corn_Res_np = np.array(KB_3_Corn_Res["Mean Reflectance"])
KB_3_Soil_np = np.array(KB_3_Soil['Mean Reflectance'])
KB_1_Corn_Res_np = np.array(KB_1_Corn_Res["Mean Reflectance"])
KB_1_Soil_np = np.array(KB_1_Soil['Mean Reflectance'])

JB_5_Soil_np = np.array(JB_5_Soil['Mean Reflectance'])
JB_5_Corn_Res_np = np.array(JB_5_Corn_Res["Mean Reflectance"])

JB_4_Soil_np = np.array(JB_4_Soil['Mean Reflectance'])
JB_4_Corn_Res_np = np.array(JB_4_Corn_Res["Mean Reflectance"])
JB_3_Soil_np = np.array(JB_3_Soil['Mean Reflectance'])
JB_3_Corn_Res_np = np.array(JB_3_Corn_Res["Mean Reflectance"])
JB_2_Soil_np = np.array(JB_2_Soil['Mean Reflectance'])
JB_2_Corn_Res_np = np.array(JB_2_Corn_Res["Mean Reflectance"])
JB_1_Soil_np = np.array(JB_1_Soil['Mean Reflectance'])
JB_1_Corn_Res_np = np.array(JB_1_Corn_Res["Mean Reflectance"])
JB_1_Soya_Bean_np = np.array(JB_1_Soya_Bean['Mean Reflectance'])
JB_0_Road_np = np.array(JB_0_Road['Mean Reflectance'])
JB_Grass_Filt_np = np.array(JB_Grass_Filt['Mean Reflectance'])

JanD_S10_Weeds_np = np.array(JanD_S10_Weeds['Mean Reflectance'])
JanD_S9_Weeds_np = np.array(JanD_S9_Weeds['Mean Reflectance'])
JanD_S9_Corn_Res_np = np.array(JanD_S9_Corn_Res['Mean Reflectance'])
JanD_S8_Bare_Soil_np = np.array(JanD_S8_Bare_Soil['Mean Reflectance'])
JanD_S8_Corn_Res_np = np.array(JanD_S8_Corn_Res['Mean Reflectance'])
JanD_S6_Weed_np = np.array(JanD_S6_Weed['Mean Reflectance'])
JanD_S6_Weed_2_np = np.array(JanD_S6_Weed_2['Mean Reflectance'])
JanD_S6_Weed_3_np = np.array(JanD_S6_Weed_3['Mean Reflectance'])
JanD_S6_Corn_Redw_np = np.array(JanD_S6_Corn_Redw['Mean Reflectance'])

# %%
""" We want to create a numpy array of the Mean Reflectances
"""
xvals = np.array(range(350, 2501, 10))
Wavelength_np = np.array(ZachA_15_Weeds["Wavelength"])
Wavelength_np_LynnW = np.array(LynnW05_CornRes["Wavelength"])

ZachA_15_Weeds_np= np.array(ZachA_15_Weeds['Mean Reflectance'])
ZachA_15_Soil_np = np.array(ZachA_15_Soil['Mean Reflectance'])
ZachA_14_Weeds_np= np.array(ZachA_14_Weeds['Mean Reflectance'])
ZachA_14_Soil_np = np.array(ZachA_14_Soil['Mean Reflectance'])
ZachA_13_Weeds_np= np.array(ZachA_13_Weeds['Mean Reflectance'])
ZachA_13_Soil_np = np.array(ZachA_13_Soil['Mean Reflectance'])
ZachA_12_Wheat_np= np.array(ZachA_12_Wheat['Mean Reflectance'])
ZachA_12_Road_np = np.array(ZachA_12_Road['Mean Reflectance'])
ZachA_11_Wheat_np= np.array(ZachA_11_Wheat['Mean Reflectance'])
ZachA_11_Soil_np = np.array(ZachA_11_Soil['Mean Reflectance'])

LynnW05_CornRes_np = np.array( LynnW05_CornRes['Mean Reflectance'])
LynnW05_Soil_np = np.array (LynnW05_Soil['Mean Reflectance'])
LynnW04_CornRes_np = np.array( LynnW04_CornRes['Mean Reflectance'])
LynnW04_Soil_np = np.array (LynnW04_Soil['Mean Reflectance'])
LynnW03_CornRes_np = np.array( LynnW03_CornRes['Mean Reflectance'])
LynnW03_Soil_np = np.array (LynnW03_Soil['Mean Reflectance'])
LynnW02_CornRes_np = np.array( LynnW02_CornRes['Mean Reflectance'])
LynnW02_Soil_np = np.array (LynnW02_Soil['Mean Reflectance'])
LynnW01_CornRes_np = np.array( LynnW01_CornRes['Mean Reflectance'])
LynnW01_Soil_np = np.array (LynnW01_Soil['Mean Reflectance'])

# %%
"""We want to calculate the interpolations for all samples using the numpy interpolation function
"""
ZachA_15_Weeds_10nm = np.interp(xvals,Wavelength_np,ZachA_15_Weeds_np)
ZachA_15_Soil_10nm = np.interp(xvals,Wavelength_np,ZachA_15_Soil_np)
ZachA_14_Weeds_10nm = np.interp(xvals,Wavelength_np,ZachA_14_Weeds_np)
ZachA_14_Soil_10nm = np.interp(xvals,Wavelength_np,ZachA_14_Soil_np)
ZachA_13_Weeds_10nm = np.interp(xvals,Wavelength_np,ZachA_13_Weeds_np)
ZachA_13_Soil_10nm = np.interp(xvals,Wavelength_np,ZachA_13_Soil_np)
ZachA_12_Wheat_10nm = np.interp(xvals,Wavelength_np,ZachA_12_Wheat_np)
ZachA_12_Road_10nm = np.interp(xvals,Wavelength_np,ZachA_12_Road_np)
ZachA_11_Wheat_10nm = np.interp(xvals,Wavelength_np,ZachA_11_Wheat_np)
ZachA_11_Soil_10nm = np.interp(xvals,Wavelength_np,ZachA_11_Soil_np)

LynnW_05_CornRes_10nm = np.interp(xvals,Wavelength_np_LynnW,LynnW05_CornRes_np)
LynnW_05_Soil_10nm = np.interp(xvals,Wavelength_np_LynnW,LynnW05_Soil_np)
LynnW_04_CornRes_10nm = np.interp(xvals,Wavelength_np_LynnW,LynnW04_CornRes_np)
LynnW_04_Soil_10nm = np.interp(xvals,Wavelength_np_LynnW,LynnW04_Soil_np)
LynnW_03_CornRes_10nm = np.interp(xvals,Wavelength_np_LynnW,LynnW03_CornRes_np)
LynnW_03_Soil_10nm = np.interp(xvals,Wavelength_np_LynnW,LynnW03_Soil_np)
LynnW_02_CornRes_10nm = np.interp(xvals,Wavelength_np_LynnW,LynnW02_CornRes_np )
LynnW_02_Soil_10nm = np.interp(xvals,Wavelength_np_LynnW,LynnW02_Soil_np)
LynnW_01_CornRes_10nm = np.interp(xvals,Wavelength_np_LynnW,LynnW01_CornRes_np)
LynnW_01_Soil_10nm = np.interp(xvals,Wavelength_np_LynnW,LynnW01_Soil_np)

# %%
"""We want to calculate the interpolations for all samples using the numpy interpolation function
"""
SK_5_Soil_10nm = np.interp(xvals,Wavelength_np, SK_5_Soil_np)
SK_5_Grass_10nm = np.interp(xvals,Wavelength_np, SK_5_Grass_np)
SK_4_Soil_10nm = np.interp(xvals,Wavelength_np, SK_4_Soil_np)
SK_4_Grass_10nm = np.interp(xvals,Wavelength_np, SK_4_Grass_np)
SK_3_Soil_10nm = np.interp(xvals,Wavelength_np, SK_3_Soil_np)
SK_3_Grass_10nm = np.interp(xvals,Wavelength_np, SK_3_Grass_np)
SK_2_Soil_10nm = np.interp(xvals,Wavelength_np, SK_2_Soil_np)
SK_2_Grass_10nm = np.interp(xvals,Wavelength_np, SK_2_Grass_np)
SK_1_Soil_10nm = np.interp(xvals,Wavelength_np, SK_1_Soil_np)
SK_1_Grass_10nm = np.interp(xvals,Wavelength_np, SK_1_Grass_np)

KB_5_Soil_10nm = np.interp(xvals,Wavelength_np, KB_5_Soil_np)
KB_5_Wheat_10nm = np.interp(xvals,Wavelength_np, KB_5_Wheat_np)
KB_5_Drying_Wheat_10nm = np.interp(xvals,Wavelength_np, KB_5_Drying_Wheat_np)
KB_5_Corn_Res_10nm = np.interp(xvals,Wavelength_np, KB_5_Corn_Res_np)
KB_4_Dry_Rye_10nm = np.interp(xvals,Wavelength_np, KB_4_Dry_Rye_np)
KB_4_Soil_10nm = np.interp(xvals,Wavelength_np, KB_4_Soil_np)
KB_3_Corn_Res_10nm = np.interp(xvals,Wavelength_np, KB_3_Corn_Res_np)
KB_3_Soil_10nm = np.interp(xvals,Wavelength_np, KB_3_Soil_np)
KB_1_Corn_Res_10nm = np.interp(xvals,Wavelength_np, KB_1_Corn_Res_np)
KB_1_Soil_10nm = np.interp(xvals,Wavelength_np, KB_1_Soil_np)

JB_5_Soil_10nm = np.interp(xvals,Wavelength_np, JB_5_Soil_np)
JB_5_Corn_Res_10nm = np.interp(xvals,Wavelength_np, JB_5_Corn_Res_np)
JB_4_Soil_10nm = np.interp(xvals,Wavelength_np, JB_4_Soil_np)
JB_4_Corn_Res_10nm = np.interp(xvals,Wavelength_np, JB_4_Corn_Res_np)
JB_3_Soil_10nm = np.interp(xvals,Wavelength_np, JB_3_Soil_np)
JB_3_Corn_Res_10nm = np.interp(xvals,Wavelength_np, JB_3_Corn_Res_np)
JB_2_Soil_10nm = np.interp(xvals,Wavelength_np, JB_2_Soil_np)
JB_2_Corn_Res_10nm = np.interp(xvals,Wavelength_np, JB_2_Corn_Res_np)
JB_1_Soil_10nm = np.interp(xvals,Wavelength_np, JB_1_Soil_np)
JB_1_Corn_Res_10nm = np.interp(xvals,Wavelength_np, JB_1_Corn_Res_np)
JB_1_Soya_Bean_10nm = np.interp(xvals,Wavelength_np, JB_1_Soya_Bean_np)
JB_0_Road_10nm = np.interp(xvals,Wavelength_np, JB_0_Road_np)
JB_Grass_Filt_10nm = np.interp(xvals,Wavelength_np, JB_Grass_Filt_np)

JanD_S10_Weeds_10nm = np.interp(xvals,Wavelength_np, JanD_S10_Weeds_np)
JanD_S9_Weeds_10nm = np.interp(xvals,Wavelength_np, JanD_S9_Weeds_np)
JanD_S9_Corn_Res_10nm = np.interp(xvals,Wavelength_np, JanD_S9_Corn_Res_np)
JanD_S8_Bare_Soil_10nm = np.interp(xvals,Wavelength_np, JanD_S8_Bare_Soil_np)
JanD_S8_Corn_Res_10nm = np.interp(xvals,Wavelength_np, JanD_S8_Corn_Res_np)
JanD_S6_Weed_10nm = np.interp(xvals,Wavelength_np, JanD_S6_Weed_np)
JanD_S6_Weed_2_10nm = np.interp(xvals,Wavelength_np, JanD_S6_Weed_2_np)
JanD_S6_Weed_3_10nm = np.interp(xvals,Wavelength_np, JanD_S6_Weed_3_np)
JanD_S6_Corn_Rewd_10nm = np.interp(xvals,Wavelength_np, JanD_S6_Corn_Redw_np)

# %%
''' we want to claculate the derivative using the gradient function
dydx = np.gradient(y,x)
'''
SK_5_Soil_derivative = np.gradient(SK_5_Soil_10nm , xvals)
SK_5_Grass_derivative = np.gradient(SK_5_Grass_10nm , xvals)
SK_4_Soil_derivative = np.gradient(SK_4_Soil_10nm , xvals)
SK_4_Grass_derivative = np.gradient(SK_4_Grass_10nm , xvals)
SK_3_Soil_derivative = np.gradient(SK_3_Soil_10nm , xvals)
SK_3_Grass_derivative = np.gradient(SK_3_Grass_10nm , xvals)
SK_2_Soil_derivative = np.gradient(SK_2_Soil_10nm , xvals)
SK_2_Grass_derivative = np.gradient(SK_2_Grass_10nm , xvals)
SK_1_Soil_derivative = np.gradient(SK_1_Soil_10nm , xvals)
SK_1_Grass_derivative = np.gradient(SK_1_Grass_10nm , xvals)

KB_5_Soil_derivative = np.gradient(KB_5_Soil_10nm , xvals)
KB_5_Wheat_derivative = np.gradient(KB_5_Wheat_10nm , xvals)
KB_5_Drying_Wheat_derivative = np.gradient(KB_5_Drying_Wheat_10nm , xvals)
KB_5_Corn_Res_derivative = np.gradient(KB_5_Corn_Res_10nm , xvals)
KB_4_Dry_Rye_derivative = np.gradient(KB_4_Dry_Rye_10nm , xvals)
KB_4_Soil_derivative = np.gradient(KB_4_Soil_10nm , xvals)
KB_3_Corn_Res_derivative = np.gradient(KB_3_Corn_Res_10nm , xvals)
KB_3_Soil_derivative = np.gradient(KB_3_Soil_10nm , xvals)
KB_1_Corn_Res_derivative = np.gradient(KB_1_Corn_Res_10nm , xvals)
KB_1_Soil_derivative = np.gradient(KB_1_Soil_10nm , xvals)

JB_5_Soil_derivative = np.gradient(JB_5_Soil_10nm , xvals)
JB_5_Corn_Res_derivative = np.gradient(JB_5_Corn_Res_10nm , xvals)
JB_4_Soil_derivative = np.gradient(JB_4_Soil_10nm , xvals)
JB_4_Corn_Res_derivative = np.gradient(JB_4_Corn_Res_10nm , xvals)
JB_3_Soil_derivative = np.gradient(JB_3_Soil_10nm , xvals)
JB_3_Corn_Res_derivative = np.gradient(JB_3_Corn_Res_10nm , xvals)
JB_2_Soil_derivative = np.gradient(JB_2_Soil_10nm , xvals)
JB_2_Corn_Res_derivative = np.gradient(JB_2_Corn_Res_10nm , xvals)
JB_1_Soil_derivative = np.gradient(JB_1_Soil_10nm , xvals)
JB_1_Corn_Res_derivative = np.gradient(JB_1_Corn_Res_10nm , xvals)
JB_1_Soya_Bean_derivative = np.gradient(JB_1_Soya_Bean_10nm , xvals)
JB_0_Road_derivative = np.gradient(JB_0_Road_10nm , xvals)
JB_Grass_Filt_derivative = np.gradient(JB_Grass_Filt_10nm , xvals)

JanD_S10_Weeds_derivative = np.gradient(JanD_S10_Weeds_10nm , xvals)
JanD_S9_Weeds_derivative = np.gradient(JanD_S10_Weeds_10nm , xvals)
JanD_S9_Corn_Res_derivative = np.gradient(JanD_S9_Corn_Res_10nm , xvals)

JanD_S8_Corn_Res_derivative = np.gradient(JanD_S8_Corn_Res_10nm , xvals)
JanD_S8_Bare_Soil_derivative = np.gradient(JanD_S8_Bare_Soil_10nm , xvals)
JanD_S6_Weed_derivative = np.gradient(JanD_S6_Weed_10nm , xvals)
JanD_S6_Weed_2_derivative = np.gradient(JanD_S6_Weed_2_10nm , xvals)
JanD_S6_Weed_3_derivative = np.gradient(JanD_S6_Weed_3_10nm , xvals)
JanD_S6_Corn_Rewd_derivative = np.gradient(JanD_S6_Corn_Rewd_10nm  , xvals)

# %%
ZachA_15_Weeds_derivative = np.gradient(ZachA_15_Weeds_10nm , xvals)
ZachA_15_Soil_derivative = np.gradient(ZachA_15_Soil_10nm , xvals)
ZachA_14_Weeds_derivative = np.gradient(ZachA_14_Weeds_10nm , xvals)
ZachA_14_Soil_derivative = np.gradient(ZachA_14_Soil_10nm , xvals)
ZachA_13_Weeds_derivative = np.gradient(ZachA_13_Weeds_10nm , xvals)
ZachA_13_Soil_derivative = np.gradient(ZachA_13_Soil_10nm , xvals)
ZachA_12_Wheat_derivative = np.gradient(ZachA_12_Wheat_10nm , xvals)
ZachA_12_Road_derivative = np.gradient(ZachA_12_Road_10nm , xvals)
ZachA_11_Wheat_derivative = np.gradient(ZachA_11_Wheat_10nm , xvals)
ZachA_11_Soil_derivative = np.gradient(ZachA_11_Soil_10nm , xvals)


LynnW_05_CornRes_derivative = np.gradient(LynnW_05_CornRes_10nm , xvals)
LynnW_05_Soil_derivative = np.gradient(LynnW_05_Soil_10nm , xvals)
LynnW_04_CornRes_derivative = np.gradient(LynnW_04_CornRes_10nm , xvals)
LynnW_04_Soil_derivative = np.gradient(LynnW_04_Soil_10nm , xvals)
LynnW_03_CornRes_derivative = np.gradient(LynnW_03_CornRes_10nm , xvals)
LynnW_03_Soil_derivative = np.gradient(LynnW_03_Soil_10nm , xvals)
LynnW_02_CornRes_derivative = np.gradient(LynnW_02_CornRes_10nm , xvals)
LynnW_02_Soil_derivative = np.gradient(LynnW_02_Soil_10nm , xvals)
LynnW_01_CornRes_derivative = np.gradient(LynnW_01_CornRes_10nm , xvals)
LynnW_01_Soil_derivative = np.gradient(LynnW_01_Soil_10nm , xvals)

# %%
''' we want to make a dataframe of all derivatives
'''
derivative_spring_2023 = pd.DataFrame({'Wavelength':xvals,
                                       'ZachA_15_Weeds_derivative': ZachA_15_Weeds_derivative,
                                       'ZachA_15_Soil_derivative': ZachA_15_Soil_derivative,
                                       'ZachA_14_Weeds_derivative': ZachA_14_Weeds_derivative,
                                       'ZachA_14_Soil_derivative':ZachA_14_Soil_derivative,
                                       'ZachA_13_Weeds_derivative':ZachA_13_Weeds_derivative,
                                       'ZachA_13_Soil_derivative': ZachA_13_Soil_derivative,
                                       'ZachA_12_Wheat_derivative ':ZachA_12_Wheat_derivative ,
                                       'ZachA_12_Road_derivative': ZachA_12_Road_derivative,
                                       'ZachA_11_Wheat_derivative':ZachA_11_Wheat_derivative,
                                       'ZachA_11_Soil_derivative': ZachA_11_Soil_derivative,
                                       'LynnW_05_CornRes_derivative': LynnW_05_CornRes_derivative,
                                       'LynnW_05_Soil_derivative': LynnW_05_Soil_derivative,
                                       'LynnW_04_CornRes_derivative ': LynnW_04_CornRes_derivative ,
                                       'LynnW_04_Soil_derivative ': LynnW_04_Soil_derivative,
                                       'LynnW_03_CornRes_derivative ': LynnW_03_CornRes_derivative,
                                       'LynnW_03_Soil_derivative':LynnW_03_Soil_derivative,
                                       'LynnW_02_CornRes_derivative ': LynnW_02_CornRes_derivative,
                                       'LynnW_02_Soil_derivative':LynnW_02_Soil_derivative,
                                       'LynnW_01_CornRes_derivative ': LynnW_01_CornRes_derivative,
                                       'LynnW_01_Soil_derivative': LynnW_01_Soil_derivative,
                                       'SK_5_Soil_derivative': SK_5_Soil_derivative,
                                       'SK_5_Grass_derivative': SK_5_Grass_derivative,
                                       'SK_4_Soil_derivative ': SK_4_Soil_derivative,
                                       'SK_4_Grass_derivative': SK_4_Grass_derivative,
                                       'SK_3_Soil_derivative' : SK_3_Soil_derivative,
                                       'SK_3_Grass_derivative': SK_3_Grass_derivative,
                                       'SK_2_Soil_derivative': SK_2_Soil_derivative,
                                       'SK_2_Grass_derivative': SK_2_Grass_derivative,
                                       'SK_1_Soil_derivative ':SK_1_Soil_derivative,
                                       'SK_1_Grass_derivative': SK_1_Grass_derivative,
                                       'KB_5_Soil_derivative':  KB_5_Soil_derivative,
                                       'KB_5_Wheat_derivative': KB_5_Wheat_derivative,
                                       'KB_5_Drying_Wheat_derivative': KB_5_Drying_Wheat_derivative,
                                       'KB_5_Corn_Res_derivative ': KB_5_Corn_Res_derivative,
                                       'KB_4_Dry_Rye_derivative': KB_4_Dry_Rye_derivative,
                                       'KB_4_Soil_derivative': KB_4_Soil_derivative,
                                       'KB_3_Corn_Res_derivative ': KB_3_Corn_Res_derivative,
                                       'KB_3_Soil_derivative': KB_3_Soil_derivative,
                                       'KB_1_Corn_Res_derivative' : KB_1_Corn_Res_derivative,
                                       'KB_1_Soil_derivative': KB_1_Soil_derivative,
                                       'JB_5_Soil_derivative': JB_5_Soil_derivative,
                                       'JB_5_Corn_Res_derivative': JB_5_Corn_Res_derivative,
                                       'JB_4_Soil_derivative': JB_4_Soil_derivative,
                                       'JB_4_Corn_Res_derivative': JB_4_Corn_Res_derivative,
                                       'JB_3_Soil_derivative': JB_3_Soil_derivative,
                                       'JB_3_Corn_Res_derivative': JB_3_Corn_Res_derivative,
                                       'JB_2_Soil_derivative': JB_2_Soil_derivative,
                                       'JB_2_Corn_Res_derivative': JB_2_Corn_Res_derivative,
                                       'JB_1_Soil_derivative': JB_1_Soil_derivative,
                                       'JB_1_Corn_Res_derivative': JB_1_Corn_Res_derivative,
                                       'JB_1_Soya_Bean_derivative': JB_1_Soya_Bean_derivative,
                                       'JB_0_Road_derivative': JB_0_Road_derivative,
                                       'JB_Grass_Filt_derivative': JB_Grass_Filt_derivative,
                                       'JanD_S10_Weeds_derivative': JanD_S10_Weeds_derivative,
                                       'JanD_S9_Weeds_derivative': JanD_S9_Weeds_derivative,
                                       'JanD_S9_Corn_Res_derivative': JanD_S9_Corn_Res_derivative,
                                       'JanD_S8_Corn_Res_derivative': JanD_S8_Corn_Res_derivative,
                                       'JanD_S8_Bare_Soil_derivative': JanD_S8_Bare_Soil_derivative,
                                       'JanD_S6_Weed_derivative': JanD_S6_Weed_derivative,
                                       'JanD_S6_Weed_2_derivative ': JanD_S6_Weed_2_derivative,
                                       'JanD_S6_Weed_3_derivative ': JanD_S6_Weed_3_derivative,
                                       'JanD_S6_Corn_Rewd_derivative': JanD_S6_Corn_Rewd_derivative












                                       } )

# %%
"""We want to plot the derivative spectra
"""
derivative_spring_2023.plot(x="Wavelength", y=['ZachA_15_Weeds_derivative',
                                        'ZachA_15_Weeds_derivative',
                                       'ZachA_15_Soil_derivative',
                                       'ZachA_14_Weeds_derivative',
                                       'ZachA_14_Soil_derivative',
                                       'ZachA_13_Weeds_derivative',
                                       'ZachA_13_Soil_derivative',
                                       'ZachA_12_Wheat_derivative ',
                                       'ZachA_12_Road_derivative',
                                       'ZachA_11_Wheat_derivative',
                                       'ZachA_11_Soil_derivative',
                                       'LynnW_05_CornRes_derivative',
                                       'LynnW_05_Soil_derivative',
                                       'LynnW_04_CornRes_derivative ' ,
                                       'LynnW_04_Soil_derivative ',
                                       'LynnW_03_CornRes_derivative ',
                                       'LynnW_03_Soil_derivative',
                                       'LynnW_02_CornRes_derivative ',
                                       'LynnW_02_Soil_derivative',
                                       'LynnW_01_CornRes_derivative ',
                                       'LynnW_01_Soil_derivative',
                                       'SK_5_Soil_derivative',
                                       'SK_5_Grass_derivative',
                                       'SK_4_Soil_derivative ',
                                       'SK_4_Grass_derivative',
                                       'SK_3_Soil_derivative' ,
                                       'SK_3_Grass_derivative',
                                       'SK_2_Soil_derivative',
                                       'SK_2_Grass_derivative',
                                       'SK_1_Soil_derivative ',
                                       'SK_1_Grass_derivative',
                                       'KB_5_Soil_derivative',
                                       'KB_5_Wheat_derivative',
                                       'KB_5_Drying_Wheat_derivative',
                                       'KB_5_Corn_Res_derivative ',
                                       'KB_4_Dry_Rye_derivative',
                                       'KB_4_Soil_derivative',
                                       'KB_3_Corn_Res_derivative ',
                                       'KB_3_Soil_derivative',
                                       'KB_1_Corn_Res_derivative',
                                       'KB_1_Soil_derivative',
                                       'JB_5_Soil_derivative',
                                       'JB_5_Corn_Res_derivative',
                                       'JB_4_Soil_derivative',
                                       'JB_4_Corn_Res_derivative',
                                       'JB_3_Soil_derivative',
                                       'JB_3_Corn_Res_derivative',
                                       'JB_2_Soil_derivative',
                                       'JB_2_Corn_Res_derivative',
                                       'JB_1_Soil_derivative',
                                       'JB_1_Corn_Res_derivative',
                                       'JB_1_Soya_Bean_derivative',
                                       'JB_0_Road_derivative',
                                       'JB_Grass_Filt_derivative',
                                       'JanD_S10_Weeds_derivative',
                                       'JanD_S9_Weeds_derivative',
                                       'JanD_S9_Corn_Res_derivative',
                                       'JanD_S8_Corn_Res_derivative',
                                       'JanD_S8_Bare_Soil_derivative',
                                       'JanD_S6_Weed_derivative',
                                       'JanD_S6_Weed_2_derivative ',
                                       'JanD_S6_Weed_3_derivative ',
                                       'JanD_S6_Corn_Rewd_derivative'



])
plt.gca().get_legend().remove()
plt.title("Derivative Spectra for all samples in 4 farms Spring 2023")
plt.ylabel("Derivative Relectance")
plt.xlabel("Wavelength (nm)")
# Out:
# Text(0.5, 0, 'Wavelength (nm)')

# %%
''' we want to show the first 10 rows of the derivative spectra
'''
derivative_spring_2023.head(10)
# Out:
#    Wavelength  ZachA_15_Weeds_derivative  ZachA_15_Soil_derivative  \
# 0         350                  -0.001065                  0.012294
# 1         360                   0.001130                  0.016511
# 2         370                   0.007323                  0.029494
# 3         380                   0.015395                  0.046133
# 4         390                   0.023278                  0.053879
# 5         400                   0.033142                  0.050415
# 6         410                   0.049315                  0.052549
# 7         420                   0.060517                  0.063444
# 8         430                   0.053286                  0.070526
# 9         440                   0.036665                  0.061641
#
#    ZachA_14_Weeds_derivative  ZachA_14_Soil_derivative  \
# 0                  -0.000208                  0.008234
# 1                  -0.000905                  0.009922
# 2                   0.003313                  0.021173
# ...

# %%
''' we want to add drdl to the wavelength to make it a string
'''
derivative_spring_2023['Wavelength'] = 'drdl' + derivative_spring_2023['Wavelength']. astype (str)
derivative_spring_2023.head(5)
# Out:
#   Wavelength  ZachA_15_Weeds_derivative  ZachA_15_Soil_derivative  \
# 0    drdl350                  -0.001065                  0.012294
# 1    drdl360                   0.001130                  0.016511
# 2    drdl370                   0.007323                  0.029494
# 3    drdl380                   0.015395                  0.046133
# 4    drdl390                   0.023278                  0.053879
#
#    ZachA_14_Weeds_derivative  ZachA_14_Soil_derivative  \
# 0                  -0.000208                  0.008234
# 1                  -0.000905                  0.009922
# 2                   0.003313                  0.021173
# 3                   0.012361                  0.037760
# 4                   0.017802                  0.042840
#
#    ZachA_13_Weeds_derivative  ZachA_13_Soil_derivative  \
# 0                  -0.002348                  0.001118
# 1                   0.001336                  0.005548
# 2                   0.007999                  0.016265
# ...

# %%
''' we want to export our result to excel
'''
derivative_spring_2023.to_excel("Winter_2023_Derivatives.xlsx")

# %%
"We want to transpose the derivatives before calculating correlation matrixes"
derivative_transpose = derivative_spring_2023.set_index('Wavelength').T
derivative_transpose.head(5)
# Out:
# Wavelength                  drdl350   drdl360   drdl370   drdl380   drdl390  \
# ZachA_15_Weeds_derivative -0.001065  0.001130  0.007323  0.015395  0.023278
# ZachA_15_Soil_derivative   0.012294  0.016511  0.029494  0.046133  0.053879
# ZachA_14_Weeds_derivative -0.000208 -0.000905  0.003313  0.012361  0.017802
# ZachA_14_Soil_derivative   0.008234  0.009922  0.021173  0.037760  0.042840
# ZachA_13_Weeds_derivative -0.002348  0.001336  0.007999  0.015365  0.022536
#
# Wavelength                  drdl400   drdl410   drdl420   drdl430   drdl440  \
# ZachA_15_Weeds_derivative  0.033142  0.049315  0.060517  0.053286  0.036665
# ZachA_15_Soil_derivative   0.050415  0.052549  0.063444  0.070526  0.061641
# ZachA_14_Weeds_derivative  0.025602  0.041659  0.049392  0.039808  0.024979
# ZachA_14_Soil_derivative   0.039731  0.043123  0.053473  0.061577  0.055165
# ZachA_13_Weeds_derivative  0.027663  0.036921  0.044197  0.040209  0.030056
#
# ...

# %%
derivative_transpose.shape
# Out:
# (62, 216)

# %%
''' we want to calculate the correlation matrix
'''
corr_matrix = derivative_transpose.corr(method = "pearson")
corr_matrix
# Out:
# Wavelength   drdl350   drdl360   drdl370   drdl380   drdl390   drdl400  \
# Wavelength
# drdl350     1.000000  0.287119  0.553993  0.984132  0.983206  0.977311
# drdl360     0.287119  1.000000  0.932220  0.259089  0.192610  0.145414
# drdl370     0.553993  0.932220  1.000000  0.560815  0.499078  0.453087
# drdl380     0.984132  0.259089  0.560815  1.000000  0.996761  0.988899
# drdl390     0.983206  0.192610  0.499078  0.996761  1.000000  0.997248
# ...              ...       ...       ...       ...       ...       ...
# drdl2460    0.339180 -0.258613 -0.052299  0.399509  0.424217  0.452700
# drdl2470   -0.311889 -0.536640 -0.551338 -0.310455 -0.290774 -0.284236
# drdl2480   -0.449447 -0.329960 -0.454800 -0.481742 -0.475264 -0.481166
# drdl2490         NaN       NaN       NaN       NaN       NaN       NaN
# drdl2500         NaN       NaN       NaN       NaN       NaN       NaN
#
# Wavelength   drdl410   drdl420   drdl430   drdl440  ...  drdl2410  drdl2420  \
# ...

# %%
''' we are checking for missing values in the correlation matrix
'''
corr_matrix.isna().sum()
# Out:
# Wavelength
# drdl350      27
# drdl360      27
# drdl370      27
# drdl380      27
# drdl390      27
#            ...
# drdl2460     27
# drdl2470     27
# drdl2480     27
# drdl2490    216
# drdl2500    216
# Length: 216, dtype: int64

# %%
corr_matrix.shape
# Out:
# (216, 216)

# %%
"""We want to drop missing values"""
corr_matrix = corr_matrix.dropna(how = 'all')
corr_matrix
# Out:
# Wavelength   drdl350   drdl360   drdl370   drdl380   drdl390   drdl400  \
# Wavelength
# drdl350     1.000000  0.287119  0.553993  0.984132  0.983206  0.977311
# drdl360     0.287119  1.000000  0.932220  0.259089  0.192610  0.145414
# drdl370     0.553993  0.932220  1.000000  0.560815  0.499078  0.453087
# drdl380     0.984132  0.259089  0.560815  1.000000  0.996761  0.988899
# drdl390     0.983206  0.192610  0.499078  0.996761  1.000000  0.997248
# ...              ...       ...       ...       ...       ...       ...
# drdl2440   -0.529889 -0.543359 -0.599590 -0.501859 -0.492407 -0.496087
# drdl2450   -0.461634 -0.650031 -0.671502 -0.435338 -0.415098 -0.408492
# drdl2460    0.339180 -0.258613 -0.052299  0.399509  0.424217  0.452700
# drdl2470   -0.311889 -0.536640 -0.551338 -0.310455 -0.290774 -0.284236
# drdl2480   -0.449447 -0.329960 -0.454800 -0.481742 -0.475264 -0.481166
#
# Wavelength   drdl410   drdl420   drdl430   drdl440  ...  drdl2410  drdl2420  \
# ...

# %%
corr_matrix.isna().sum()
# Out:
# Wavelength
# drdldrdl350       0
# drdldrdl360       0
# drdldrdl370       0
# drdldrdl380       0
# drdldrdl390       0
#                ...
# drdldrdl2460      0
# drdldrdl2470      0
# drdldrdl2480      0
# drdldrdl2490    189
# drdldrdl2500    189
# Length: 216, dtype: int64

# %%
"There are still missing values so we drop columns with missing values"
corr_matrix = corr_matrix.dropna(axis = 1)
corr_matrix
# Out:
# Wavelength   drdl350   drdl360   drdl370   drdl380   drdl390   drdl400  \
# Wavelength
# drdl350     1.000000  0.287119  0.553993  0.984132  0.983206  0.977311
# drdl360     0.287119  1.000000  0.932220  0.259089  0.192610  0.145414
# drdl370     0.553993  0.932220  1.000000  0.560815  0.499078  0.453087
# drdl380     0.984132  0.259089  0.560815  1.000000  0.996761  0.988899
# drdl390     0.983206  0.192610  0.499078  0.996761  1.000000  0.997248
# ...              ...       ...       ...       ...       ...       ...
# drdl2440   -0.529889 -0.543359 -0.599590 -0.501859 -0.492407 -0.496087
# drdl2450   -0.461634 -0.650031 -0.671502 -0.435338 -0.415098 -0.408492
# drdl2460    0.339180 -0.258613 -0.052299  0.399509  0.424217  0.452700
# drdl2470   -0.311889 -0.536640 -0.551338 -0.310455 -0.290774 -0.284236
# drdl2480   -0.449447 -0.329960 -0.454800 -0.481742 -0.475264 -0.481166
#
# Wavelength   drdl410   drdl420   drdl430   drdl440  ...  drdl2390  drdl2400  \
# ...

# %%
"""Now our matrix is clean"""
corr_matrix.isna().sum()
# Out:
# Wavelength
# drdl350     0
# drdl360     0
# drdl370     0
# drdl380     0
# drdl390     0
#            ..
# drdl2440    0
# drdl2450    0
# drdl2460    0
# drdl2470    0
# drdl2480    0
# Length: 189, dtype: int64

# %%
'''We can now plot the correlation matrix'''
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap='Reds')
plt.title('Correlation matrix',
          fontsize=18)
plt.show()

# %%
'''We want to calculate the PCA of the correlation matrix'''
from sklearn.decomposition import PCA


pca = PCA(n_components=corr_matrix.shape[1])
pca.fit(corr_matrix)
# Reformat and view results
loadings = pd.DataFrame(pca.components_.T,
columns=['PC%s' % _ for _ in range(len(corr_matrix.columns))],
index=corr_matrix.columns)
print(loadings)

plt.plot(pca.explained_variance_ratio_)
plt.ylabel('Explained Variance')
plt.xlabel('Components')
plt.show()
# Out:
#                  PC0       PC1       PC2       PC3       PC4       PC5  \
# Wavelength
# drdl350    -0.058631 -0.051813 -0.140961  0.021075 -0.027176 -0.082879
# drdl360    -0.095756  0.031466 -0.009841 -0.015700  0.021306 -0.006243
# drdl370    -0.090847  0.021659 -0.071669 -0.001203  0.021525 -0.042559
# drdl380    -0.048933 -0.044079 -0.155969  0.025863 -0.018858 -0.090794
# drdl390    -0.044776 -0.050486 -0.155352  0.025195 -0.025755 -0.090762
# ...              ...       ...       ...       ...       ...       ...
# drdl2440    0.082727  0.037631  0.064944  0.041853  0.001394  0.035061
# drdl2450    0.093043  0.036246  0.038105  0.037364  0.006061  0.049338
# drdl2460    0.037250 -0.013131 -0.128061 -0.004009  0.027786 -0.084810
# drdl2470    0.069314  0.007308  0.044621  0.042036  0.001432  0.012485
# drdl2480    0.038848  0.018169  0.099621  0.030389 -0.010382  0.070758
#
#                  PC6       PC7       PC8       PC9  ...     PC179     PC180  \
# ...

# %%
"""
CODE ENDS HERE
"""
# Out:
# '\nCODE ENDS HERE\n'

# %%
'''We want to interpolate the 1nm data at 10nm
'''
#We first convert the wavelength, and 1nm mean reflectance to numpy arrays
sk_1_grass_wavelength_np = np.array(sk_1_grass["Wavelength"])
sk_1_grass_mean_np = np.array(sk_1_grass["Mean"])

#we create the intervals of 10nm, starting from 350nm
xvals = np.array(range(350, 2501, 10))

#we use the numpy.interp to do the interpolation for (xval,x,y)
y_interp = np.interp(xvals,sk_1_grass_wavelength_np,sk_1_grass_mean_np)

# %%
#Now we want to look at the interpolated data at 10nm
ten_nm_interpolated_data = pd.DataFrame({'ten_nm_wavelength':xvals,'ten_nm_reflectance': y_interp} )
ten_nm_interpolated_data.head()
# Out:
#    ten_nm_wavelength  ten_nm_reflectance
# 0                350            0.971833
# 1                360            0.899792
# 2                370            0.864708
# 3                380            0.871583
# 4                390            0.882175

# %%
'''we plot the interpolated results against the created 10nm intervals
'''
plt.plot(xvals,y_interp)

plt.title("10nm Interpolated Reflectance")
plt.xlabel("Wavelength")
plt.ylabel("Reflectance")
plt.show()

# %%
''' we want to claculate the derivative using the gradient function
dydx = np.gradient(y,x)
'''
derivative = np.gradient(y_interp, xvals)
plt.plot(xvals,derivative)
plt.title("Derivative Spectra on the 10nm Centres")
plt.xlabel("Wavelength")
plt.ylabel("Derivative Reflectance")
# Out:
# Text(0, 0.5, 'Derivative Reflectance')

# %%
''' We want to generate summary plot for the 1 and 10 nm,
 and the derivative spectra

'''
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(xvals, y_interp, 'ro')
ax1.plot(sk_1_grass.Wavelength, sk_1_grass.Mean, 'b-')
ax2.plot(xvals,derivative, "-")

ax1.set_xlabel("Wavelength")
ax1.set_ylabel("Reflectance")
ax2.set_ylabel("Derivative Spectra")
plt.title("Summary Spectral Plots")
ax1.legend(labels = ['10nm Reflectance','1nm Reflectance', 'Derivative Spectra'])
ax2.legend(labels = ["Derivative Spectra"], loc="upper left")
plt.show()


# plt.plot(xvals,y_interp, "*")
# plt.plot(sk_1_grass.Wavelength, sk_1_grass.Mean, "-")
# plt.plot(xvals,derivative, "--")
# plt.title("Summary Spectral Plots")
# plt.xlabel("Wavelength")
# plt.ylabel("Reflectance")
# plt.legend(labels = ['10nm Reflectance','1nm Reflectance','Derivative Spectra'])

# %%
ten_nm_interpolated_data['derivative'] = derivative
ten_nm_interpolated_data
# Out:
#      ten_nm_wavelength  ten_nm_reflectance  derivative
# 0                  350            0.971833   -0.007204
# 1                  360            0.899792   -0.005356
# 2                  370            0.864708   -0.001410
# 3                  380            0.871583    0.000873
# 4                  390            0.882175    0.003025
# ..                 ...                 ...         ...
# 211               2460            1.680669   -0.012969
# 212               2470            1.302918   -0.016027
# 213               2480            1.360125    0.002860
# 214               2490            1.360125    0.000000
# 215               2500            1.360125    0.000000
#
# [216 rows x 3 columns]

# %%
'''we want to export the data to excel file'''
ten_nm_interpolated_data.to_excel("ten_nm_interpolated_data.xlsx")
print(ten_nm_interpolated_data)
# Out:
#      ten_nm_wavelength  ten_nm_reflectance  derivative
# 0                  350            0.971833   -0.007204
# 1                  360            0.899792   -0.005356
# 2                  370            0.864708   -0.001410
# 3                  380            0.871583    0.000873
# 4                  390            0.882175    0.003025
# ..                 ...                 ...         ...
# 211               2460            1.680669   -0.012969
# 212               2470            1.302918   -0.016027
# 213               2480            1.360125    0.002860
# 214               2490            1.360125    0.000000
# 215               2500            1.360125    0.000000
#
# [216 rows x 3 columns]

# %%
ten_nm_interpolated_data.drop('ten_nm_reflectance', axis = 1).corr(method='pearson', min_periods=50)
# Out:
#                    ten_nm_wavelength  derivative
# ten_nm_wavelength           1.000000   -0.199444
# derivative                 -0.199444    1.000000

# %%
""" CODE ENDS HERE"""
# Out:
# ' CODE ENDS HERE'

# %%
#'''we want to calculate the moving average of the reflectance'''

# we calculate the simple moving average, using window size of 10nm

#sk_1_grass['moving_average'] = sk_1_grass['Mean'].rolling(10).mean()

# we want to drop the NA values for the first nine rows after calculating the moving average
#sk_1_grass['moving_average'].dropna(inplace=True)

# we make sure the columns are indicated in the table
#sk_1_grass.columns

# %%
#sk_1_grass.moving_average[0:30] # we are just looking at the moving average

# %%
'''What we want to do is to match the 10nm dataframe created above with the moving
average reflectance. The first moving average starts from the 10th row (row 9).
We want to select the moving averages in intervals of 10 and macth
them with the 10nm wavelengths with centre
starting from 355nm.'''

#We slice the moving averages 10nm intervals


# len(sk_1_grass.moving_average[9:1922:10])
# Out:
# 192

# %%
#What we want to do next is to match the centre of the moving averages to the centre of the 10nm bands
#we start from 355 to 365, etc. in 10nm intervals
# ten_nm = [i for i in range(355,2275,10)]
# len(ten_nm)
# Out:
# 192

# %%
# we convert the list  of 10nm centres to dataframe

# W_ten_nm = pd.DataFrame({"ten_nm": ten_nm, "centered_mov_av":sk_1_grass.moving_average[9:1922:10]} )
# W_ten_nm

# %%
'''We want to
    plot the moving averages against the 10nm centers
'''
# plt.plot(W_ten_nm.ten_nm, W_ten_nm.centered_mov_av)
# plt.title("10nm Moving Average Reflectance")
# plt.xlabel("Wavelength")
# plt.ylabel("Reflectance")
# Out:
# 'We want to\n    plot the moving averages against the 10nm centers\n'

# %%
''' We want to perform the first derivative of the 10 nm spectra drdl

             '''
# wavelegth_diff = W_ten_nm.ten_nm.diff(periods=2)
# reflectance_diff = W_ten_nm.centered_mov_av.diff(periods=2)
# derivative = reflectance_diff/wavelegth_diff
# derivative
# Out:
# ' We want to perform the first derivative of the 10 nm spectra drdl\n\n             '

# %%
""" we create a new 10nm list starting from 365nm"""
'''we drop the first endpoint (350nm) and move
the 10nm wavlength one row up to match the centers ,
                             '''
# new_ten_nm = [i for i in range(365,2285,10)]
# len(new_ten_nm)
# Out:
# 'we drop the first endpoint (350nm) and move\nthe 10nm wavlength one row up to match the centers ,\n                             '

# %%
# len (derivative)

# %%
# derivative_reflectance = pd.DataFrame({"new_ten_nm": new_ten_nm, "derivative": derivative})
# derivative_reflectance

# %%
'''We want to
    plot the derivative spectra against the 10nm centers
    starting from 365nm.
    What we did no do here is that we eliminated the first end point (350nm)
    We also kept the last endpoint to 20nm difference but not 10nm
'''
# plt.plot(derivative_reflectance.new_ten_nm, derivative_reflectance.derivative)
# plt.title("10nm derivative spectra")
# plt.xlabel("Center Wavelength")
# plt.ylabel("Derivative Reflectace")
# Out:
# 'We want to\n    plot the derivative spectra against the 10nm centers\n    starting from 365nm.\n    What we did no do here is that we eliminated the first end point (350nm)\n    We also kept the last endpoint to 20nm difference but not 10nm\n'
